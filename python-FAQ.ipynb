# %%
a = ['Apple', 'Mango', 'Banana']
b = a.copy()

a.remove('Banana')
print(a)
print(b)
# Out:
# ['Apple', 'Mango']
# ['Apple', 'Mango', 'Banana']

# %%
a = ['Apple', ['Mango','Green'], 'Banana']
b = a.copy()

a.remove('Banana')
b[1][1] = 'Yellow'
print(a)
print(b)
# Out:
# ['Apple', ['Mango', 'Yellow']]
# ['Apple', ['Mango', 'Yellow'], 'Banana']
